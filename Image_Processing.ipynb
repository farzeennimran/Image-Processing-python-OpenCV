# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **1.1 Perform Enhancement of Image using these techniques by OpenCv**

# %%
img = cv2.imread('/content/firstgrey.webp', cv2.IMREAD_GRAYSCALE)

# %% [markdown]
# **1. Histogram Equalization (Redistributing Pixels)**

# %%
image = cv2.imread('/content/firstgrey.webp')

plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

equalized_image = cv2.equalizeHist(gray_image)

cv2.imwrite('equalized.jpg', equalized_image)

plt.subplot(1, 2, 2)
plt.title("equalized")
plt.imshow(equalized_image)
plt.show()

plt.subplot(222), plt.plot(equalized_image, color='r')
plt.show()

# %% [markdown]
# **Sharpening (enhance Edges & Details)**

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

image = cv2.imread('/content/firstgrey.webp')

plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

kernel = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])
sharpened_image = cv2.filter2D(image, -1, kernel)
cv2.imwrite('sharpened_image.jpg', sharpened_image)

plt.subplot(1, 2, 2)
plt.title("Sharpening")
plt.imshow(sharpened_image)
plt.show()

# %% [markdown]
# **Color Balance (Correct Color Cast)**

# %%
image = cv2.imread('/content/firstgrey.webp')

plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

image = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)

image[:, :, 0] = image[:, :, 0] * 0.7
image[:, :, 1] = image[:, :, 1] * 1.5
image[:, :, 2] = image[:, :, 2] * 0.5

image2 = cv2.cvtColor(image, cv2.COLOR_HSV2BGR)
cv2.imwrite('enhanced coloured.jpg', image2)

plt.subplot(1, 2, 2)
plt.title("enhanced coloured")
plt.imshow(image2)
plt.show()

# %% [markdown]
# **Noise Reduction (Remove Noise)**

# %%
#Import the necessary libraries
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Load the image
image = cv2.imread('/content/firstgrey.webp')

#Plot the original image
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

# Remove noise using a median filter
filtered_image = cv2.medianBlur(image, 11)

#Save the image
cv2.imwrite('Median Blur.jpg', filtered_image)

#Plot the blured image
plt.subplot(1, 2, 2)
plt.title("Noise Removed")
plt.imshow(filtered_image)
plt.show()

# %% [markdown]
# **1.2 Edge Dectection using following techniques**

# %% [markdown]
# **1. Gradient Filtering using Sobel Operator**

# %%
img = cv2.imread('/content/firstgrey.webp')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (3, 3), 0)


sobelx = cv2.Sobel(blur, cv2.CV_64F, 1, 0, ksize=3)
sobely = cv2.Sobel(blur, cv2.CV_64F, 0, 1, ksize=3)

mag, angle = cv2.cartToPolar(sobelx, sobely, angleInDegrees=True)

edges = cv2.threshold(mag, 50, 255, cv2.THRESH_BINARY)[1]
plt.imshow(edges)

# %% [markdown]
# **2. Laplacian-based but keep in mind to convert absolute values of laplacian**

# %%
img = cv2.imread('/content/firstgrey.webp')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (3, 3), 0)
laplacian = cv2.Laplacian(blur, cv2.CV_64F)
edges = cv2.threshold(laplacian, 50, 255, cv2.THRESH_BINARY)[1]
plt.imshow(edges)

# %% [markdown]
# **1.3 Noise Removal using Arithmetic Filtering**

# %% [markdown]
# **1. load noise image**

# %%
image = cv2.imread('/content/download.jpg')

# %% [markdown]
# **2. apply arithmetic mean for kernal size = 3 & 5**

# %%
from google.colab.patches import cv2_imshow
import cv2
noisy_image = cv2.imread('/content/download.jpg', 0)

filtered_image = cv2.blur(noisy_image, (3, 3))
filteredimage = cv2.blur(noisy_image, (5, 5))

cv2_imshow(noisy_image)
cv2_imshow(filteredimage)
# Out:
# <PIL.Image.Image image mode=L size=224x225>
# <PIL.Image.Image image mode=L size=224x225>

# %% [markdown]
# **1.4 Add Noise by Salt & Pepper**

# %%
from google.colab.patches import cv2_imshow

image = cv2.imread('/content/firstgrey.webp')
grayimage = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

noise_image_1 = np.copy(grayimage)
height, width = noise_image_1.shape
num_pixels = int(0.05 * height * width)
coords = [np.random.randint(0, high=i, size=num_pixels) for i in noise_image_1.shape]
noise_image_1[tuple(coords)] = 0 if np.random.rand() < 0.5 else 255

noise_image_2 = np.copy(grayimage)
num_pixels = int(0.07 * height * width)
coords = [np.random.randint(0, high=i, size=num_pixels) for i in noise_image_2.shape]
noise_image_2[tuple(coords)] = 0 if np.random.rand() < 0.5 else 255

cv2_imshow(noise_image_1)
cv2_imshow(noise_image_2)
# Out:
# <PIL.Image.Image image mode=L size=856x376>
# <PIL.Image.Image image mode=L size=856x376>

# %% [markdown]
# **1.5 Compress Image using following Libraries**

# %%
from PIL import Image
image = Image.open('/content/firstgrey.webp')
image.save('img.jpg', optimize=True, quality=85)

import cv2
image = cv2.imread('img.jpg')
compression_params = [cv2.IMWRITE_JPEG_QUALITY, 85]
cv2=cv2.imwrite('image.jpg', image, compression_params)

# %% [markdown]
# **1.6 Perform Image Filtering by these techniques**

# %%
from google.colab.patches import cv2_imshow
import cv2

# %%
image = cv2.imread('/content/firstgrey.webp')
blurimage = cv2.GaussianBlur(image, (5, 5), 0)
cv2_imshow(blurimage)
# Out:
# <PIL.Image.Image image mode=RGB size=856x376>

# %%
image = cv2.imread('/content/firstgrey.webp')
medianimage = cv2.medianBlur(image, 5)
cv2_imshow(medianimage)
# Out:
# <PIL.Image.Image image mode=RGB size=856x376>

# %%
image = cv2.imread('/content/firstgrey.webp')
bilateralimage = cv2.bilateralFilter(image, 9, 75, 75)
cv2_imshow(bilateralimage)
# Out:
# <PIL.Image.Image image mode=RGB size=856x376>
